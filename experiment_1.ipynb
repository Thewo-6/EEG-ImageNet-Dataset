# %%
import mne

montage = mne.channels.read_dig_fif("data/mode/montage.fif")
print(montage)
# Out:
# <DigMontage | 0 extras (headshape), 0 HPIs, 0 fiducials, 69 channels>
# C:\Users\Maxal\AppData\Local\Temp\ipykernel_34616\1355630332.py:3: RuntimeWarning: This filename (data/mode/montage.fif) does not conform to MNE naming conventions. All montage files should end with -dig.fif or -dig.fif.gz
#   montage = mne.channels.read_dig_fif("data/mode/montage.fif")
